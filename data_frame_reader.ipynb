# %%
import os
os.chdir(r'C:\Users\Navid\Documents\ds_salary_proj')

# %%
import pandas as pd

# %%
df1 = pd.read_csv('df_data_scientist1.txt')
df2 = pd.read_csv('df_data_analyst1.txt')
df3 = pd.read_csv('df_data_scientist2.txt')
df4 = pd.read_csv('df_data_analyst2.txt')
df5 = pd.read_csv('df_data_engineer.txt')
df6 = pd.read_csv('df_machine_learning.txt')
df7 = pd.read_csv('df_data_scientist3.txt')
df8 = pd.read_csv('df_data_scientist4.txt')
df9 = pd.read_csv('df_data_analyst3.txt')
df10 = pd.read_csv('df_data_scientist5.txt')
df11 = pd.read_csv('df_data_architect.txt')
df12 = pd.read_csv('df_data_scientist6.txt')
df13 = pd.read_csv('df_data_scientist7')

# %%
df = df1.append(df2).append(df3).append(df4).append(df5).append(df6).append(df7).append(df8).append(df9).append(df10).append(df11).append(df12).append(df13)

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df = df[df.duplicated().values != True]

# %%
df = df[df['Salary Range'] != '-1']

# %%
df.to_csv('df_salary')

# %%
df.shape
# Out:
# (1266, 14)

# %%
df13.shape
# Out:
# (400, 15)

# %%
df13[df13['Salary Range'] != '-1']
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 2             2  Aviation Data Scientist and Machine Learning E...
# 6             6                                    Nurse Scientist
# 8             8                                       Data Analyst
# 9             9            Business Systems Analyst (Data Analyst)
# ..          ...                                                ...
# 392         392                           Product and Data Analyst
# 393         393                                     Data Scientist
# 394         394                Machine Learning Research Scientist
# 398         398                              Senior Data Scientist
# 399         399                                Data Scientist, Sr.
#
#                            Salary Range  \
# 0          $98k-$154k\n(Glassdoor Est.)
# 2         $106k-$182k\n(Glassdoor Est.)
# ...
